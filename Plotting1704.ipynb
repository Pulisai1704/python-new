# %% [markdown]
# <a href="https://colab.research.google.com/github/Pulisai1704/python-new/blob/Module-4/Plotting1704.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([-23, 38])
ypoints = np.array([-53, 40])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Matplotlib Bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([5, 10, 3, 15])
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Matplotlib Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(150, 40, 350)
plt.hist(x)
plt.show()

# %% [markdown]
# ## Matplotlib Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([45, 25, 25, 5])
mylabels = ["cars", "tractors", "bikes", "autos"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## Plotting Without Line

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([10, 40])
ypoints = np.array([30, 60])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# ## Multiple Points

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([10, 20, 60, 80])
ypoints = np.array([30, 80, 10, 100])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ## Default X-Points

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([5, 10, 3, 12, 7, 9])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %% [markdown]
# ## Markers

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([13, 18, 11, 110])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([4, 9, 2, 11])
plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# ## marker size

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(ypoints, marker = 's', ms = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([4, 9, 2, 11])
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([31, 81, 11, 100])
plt.plot(ypoints, marker = 'o', ms = 25, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([4, 9, 2, 11])
plt.plot(ypoints, marker = 'o', ms = 50, mfc = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([4, 9, 2, 11])
plt.plot(ypoints, marker = 's', ms = 30, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([13, 18, 11, 110])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([13, 18, 11, 110])
plt.plot(ypoints, marker = 's', ms = 20, mec = 'r', mfc = 'g')
plt.show()

# %% [markdown]
# ## Matplotlib Line

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([23, 19, 12, 40])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([23, 19, 12, 40])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %% [markdown]
# ## line colour

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([13, 18, 10, 40])
plt.plot(ypoints, color = 'blue')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([1, 8, 10, 50])
plt.plot(ypoints, color = 'green')
plt.show()

# %% [markdown]
# ## Line Width

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([31, 18, 12, 10])
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([4, 10, 1, 10])
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# ## Multiple Line

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([4, 10, 1, 10])
y2 = np.array([31, 18, 12, 10])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# ## Matplotlib Labels

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([82, 85, 93, 95, 103, 105, 110, 116, 121, 125])
y = np.array([244, 255, 266, 273, 287, 298, 305, 314, 320, 360])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# ## colors

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["mangoes", "carrots", "kevi", "grapes"]
mycolors = ["yellow", "orange", "brown", "green"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## shadow

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.4, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.3, 1, 0.1, 0.2]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## bar graps

# %%
import matplotlib.pyplot as plt
import numpy as np
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
plt.show()

# %% [markdown]
# ## Horizontal Bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([26, 28, 31, 60])
plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Bar Color

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([34, 32, 12, 50])
plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([34, 32, 12, 50])
plt.bar(x, y, color = "blue")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "green")
plt.show()
plt.bar(x, y, color = "orange")
plt.show()
plt.bar(x, y, color = "blue")
plt.show()

# %% [markdown]
# Bar Width

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([13, 18, 11, 110])
plt.bar(x, y, width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([5, 9, 1, 20])
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ## Add Grid Lines to a Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([250, 260, 270, 280, 290, 300, 310, 320, 330, 340])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([82, 83, 94, 93, 110, 113, 114, 115, 120, 125])
y = np.array([243, 256, 260, 275, 280, 294, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# ## Display Multiple Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
#plot 2:
x = np.array([1, 2, 3, 4])
y = np.array([4, 9, 1, 10])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([10, 11, 12, 13])
y = np.array([31, 81, 11, 110])
plt.subplot(3, 1, 1)
plt.plot(x,y)
#plot 2:
x = np.array([20,21, 22, 23])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 1)
plt.plot(x,y)
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 2)
plt.plot(x,y)
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 3)
plt.plot(x,y)
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 4)
plt.plot(x,y)
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 5)
plt.plot(x,y)
x = np.array([10, 11, 12, 13])
y = np.array([23, 28, 1, 210])
plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Matplotlib Scatter

# %% [markdown]
# ## Creating Scatter Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'green')
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ## size

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes, alpha=0.5)
plt.show()

# %% [markdown]
# ## Combine Color Size and Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# ## Plot a Circle in Matplotlib

# %%
import matplotlib.pyplot as plt 
figure, axes = plt.subplots() 
cc = plt.Circle(( 0.4 , 0.4 ), 0.4 ) 
axes.set_aspect( 1 ) 
axes.add_artist( cc ) 
plt.title( 'line Circle' ) 
plt.show()

# %% [markdown]
# ##Matplotlib hollow circle

# %%
import matplotlib.pyplot as plt 
plt.scatter( 0 , 0 , s=10000 ,  facecolors='none', edgecolors='blue' )  
plt.xlim( -0.4 , 0.4 ) 
plt.ylim( -0.4 , 0.4 ) 
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter( 0 , 0 , s=10000 ,  facecolors='none', edgecolors='red' )  
plt.xlim( -0.6 , 0.4 ) 
plt.ylim( -0.4 , 0.4 ) 
plt.show()
